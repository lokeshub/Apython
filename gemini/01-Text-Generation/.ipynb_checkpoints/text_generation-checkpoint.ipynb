# %%
# !pip install google-genai

# %%
from google import genai

# %%
apiKey = "fake Key"

# %%
client = genai.Client(api_key=apiKey)

# %%
response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Explain why the sky is blue to a five-year-old."
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 response = client.models.generate_content(
#       2     model="gemini-2.0-flash",
#       3     contents="Explain why the sky is blue to a five-year-old."
#       4 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\google\genai\models.py:5709, in Models.generate_content(self, model, contents, config)
#    5707 while remaining_remote_calls_afc > 0:
#    5708   i += 1
# -> 5709   response = self._generate_content(
#    5710       model=model, contents=contents, config=parsed_config
#    5711   )
#    5713   function_map = _extra_utils.get_function_map(parsed_config)
#    5714   if not function_map:
#
# ...
