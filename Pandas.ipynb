# %% [markdown]
# # Pandas

# %%
# download data from stack overflow annual developer survey

# %%
import pandas as pd

# %%
df = pd.read_csv('data.txt')

# %%
df
# Out:
#       ResponseId                      MainBranch              Age  \
# 0              1  I am a developer by profession  25-34 years old
# 1              2  I am a developer by profession  25-34 years old
# 2              3  I am a developer by profession  35-44 years old
# 3              4  I am a developer by profession  35-44 years old
# 4              5  I am a developer by profession  35-44 years old
# ...          ...                             ...              ...
# 3998        3999  I am a developer by profession  25-34 years old
# 3999        4000  I am a developer by profession  35-44 years old
# 4000        4001  I am a developer by profession  25-34 years old
# 4001        4002  I am a developer by profession  25-34 years old
# 4002        4003  I am a developer by profession  35-44 years old
#
#                                               EdLevel  \
# 0     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1                 Associate degree (A.A., A.S., etc.)
# ...

# %%
df.shape
# Out:
# (4003, 172)

# %%
df.head() # displays 5 top rows
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# ...

# %%
df.tail(2)
# Out:
#       ResponseId                      MainBranch              Age  \
# 4001        4002  I am a developer by profession  25-34 years old
# 4002        4003  I am a developer by profession  35-44 years old
#
#                                               EdLevel Employment  \
# 4001  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Employed
# 4002     Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
#
#                                          EmploymentAddl  WorkExp  \
# 4001                                  None of the above     12.0
# 4002  Caring for dependents (children, elderly, etc....     18.0
#
#                                         LearnCodeChoose  \
# 4001  Yes, I am not new to coding but am learning ne...
# 4002  Yes, I am not new to coding but am learning ne...
#
#                                               LearnCode  \
# 4001  Other online resources (e.g. standard search, ...
# 4002  Other online resources (e.g. standard search, ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4003 entries, 0 to 4002
# Columns: 172 entries, ResponseId to JobSat
# dtypes: float64(52), int64(1), object(119)
# memory usage: 5.3+ MB

# %% [markdown]
# ###### Data frame is like dictionary of lists from python
# Series are rows of single column

# %%
people = {
    "first":["Jai", "Tom", "Ram"],
    "last":["Sharma", "Thomas", "Verma"],
    "email":["sharmaji@gmail.com", "tony@gmail.com", "ramgopal@gmail.com"]
}

# %%
print(people["first"])
# Out:
# ['Jai', 'Tom', 'Ram']

# %%
df1 = pd.DataFrame(people)

# %%
df1
# Out:
#   first    last               email
# 0   Jai  Sharma  sharmaji@gmail.com
# 1   Tom  Thomas      tony@gmail.com
# 2   Ram   Verma  ramgopal@gmail.com

# %%
type(df1["email"]) #Series are rows of single column
# Out:
# pandas.core.series.Series

# %%
df1["email"]  # Python way
# Out:
# 0    sharmaji@gmail.com
# 1        tony@gmail.com
# 2    ramgopal@gmail.com
# Name: email, dtype: object

# %%
df1.email  # DataFrame way
# Out:
# 0    sharmaji@gmail.com
# 1        tony@gmail.com
# 2    ramgopal@gmail.com
# Name: email, dtype: object

# %%
df1[["last", "email"]]  # change columns sequence
# Out:
#      last               email
# 0  Sharma  sharmaji@gmail.com
# 1  Thomas      tony@gmail.com
# 2   Verma  ramgopal@gmail.com

# %%
 # columns
df1.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df1.iloc[0]
# Out:
# first                   Jai
# last                 Sharma
# email    sharmaji@gmail.com
# Name: 0, dtype: object

# %%
df1.iloc[1]
# Out:
# first               Tom
# last             Thomas
# email    tony@gmail.com
# Name: 1, dtype: object

# %%
df1
# Out:
#   first    last               email
# 0   Jai  Sharma  sharmaji@gmail.com
# 1   Tom  Thomas      tony@gmail.com
# 2   Ram   Verma  ramgopal@gmail.com

# %%
df1.iloc[2]
# Out:
# first                   Ram
# last                  Verma
# email    ramgopal@gmail.com
# Name: 2, dtype: object

# %%
df1.iloc[1,1] # second item second row
# Out:
# 'Thomas'

# %%
df1
# Out:
#   first    last               email
# 0   Jai  Sharma  sharmaji@gmail.com
# 1   Tom  Thomas      tony@gmail.com
# 2   Ram   Verma  ramgopal@gmail.com

# %%
df1.iloc[[0, 1],2]  # first and second rows third column
# Out:
# 0    sharmaji@gmail.com
# 1        tony@gmail.com
# Name: email, dtype: object

# %%
df1.iloc[[0,1],1]  # first and second rows second column
# Out:
# 0    Sharma
# 1    Thomas
# Name: last, dtype: object

# %%
df1.iloc[[1,2], 0]
# Out:
# 1    Tom
# 2    Ram
# Name: first, dtype: object

# %%
df1.iloc[[0,2]]  # Only first and third rows
# Out:
#   first    last               email
# 0   Jai  Sharma  sharmaji@gmail.com
# 2   Ram   Verma  ramgopal@gmail.com

# %%
# loc allows by searching using label or column name
df1.loc[[0,2], ["last", "first"]]  # first and third rows and indexed by key
# Out:
#      last first
# 0  Sharma   Jai
# 2   Verma   Ram

# %%
df.head
# Out:
# <bound method NDFrame.head of       ResponseId                      MainBranch              Age  \
# 0              1  I am a developer by profession  25-34 years old
# 1              2  I am a developer by profession  25-34 years old
# 2              3  I am a developer by profession  35-44 years old
# 3              4  I am a developer by profession  35-44 years old
# 4              5  I am a developer by profession  35-44 years old
# ...          ...                             ...              ...
# 3998        3999  I am a developer by profession  25-34 years old
# 3999        4000  I am a developer by profession  35-44 years old
# 4000        4001  I am a developer by profession  25-34 years old
# 4001        4002  I am a developer by profession  25-34 years old
# 4002        4003  I am a developer by profession  35-44 years old
#
#                                               EdLevel  \
# 0     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=172)

# %%
df["Employment"].head()
# Out:
# 0                                             Employed
# 1                                             Employed
# 2    Independent contractor, freelancer, or self-em...
# 3                                             Employed
# 4    Independent contractor, freelancer, or self-em...
# Name: Employment, dtype: object

# %%
df.loc[0]
# Out:
# ResponseId                                                           1
# MainBranch                              I am a developer by profession
# Age                                                    25-34 years old
# EdLevel                Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                    Employed
#                                             ...
# AIAgentExtWrite                                                    NaN
# AIHuman                                When I don’t trust AI’s answers
# AIOpen                           Troubleshooting, profiling, debugging
# ConvertedCompYearly                                            61256.0
# JobSat                                                            10.0
# Name: 0, Length: 172, dtype: object

# %%
df.loc[0:2, "Employment"]
# Out:
# 0                                             Employed
# 1                                             Employed
# 2    Independent contractor, freelancer, or self-em...
# Name: Employment, dtype: object

# %%
df1
# Out:
#   first    last               email
# 0   Jai  Sharma  sharmaji@gmail.com
# 1   Tom  Thomas      tony@gmail.com
# 2   Ram   Verma  ramgopal@gmail.com

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#    index first    last               email
# 0      0   Jai  Sharma  sharmaji@gmail.com
# 1      1   Tom  Thomas      tony@gmail.com
# 2      2   Ram   Verma  ramgopal@gmail.com

# %%
df1.reset_index(inplace=False)
# Out:
#    level_0  index first    last               email
# 0        0      0   Jai  Sharma  sharmaji@gmail.com
# 1        1      1   Tom  Thomas      tony@gmail.com
# 2        2      2   Ram   Verma  ramgopal@gmail.com

# %%
df1
# Out:
#    index first    last               email
# 0      0   Jai  Sharma  sharmaji@gmail.com
# 1      1   Tom  Thomas      tony@gmail.com
# 2      2   Ram   Verma  ramgopal@gmail.com

# %%
df1.reset_index(drop=True)
# Out:
#    index first    last               email
# 0      0   Jai  Sharma  sharmaji@gmail.com
# 1      1   Tom  Thomas      tony@gmail.com
# 2      2   Ram   Verma  ramgopal@gmail.com

# %%
df1
# Out:
#    index first    last               email
# 0      0   Jai  Sharma  sharmaji@gmail.com
# 1      1   Tom  Thomas      tony@gmail.com
# 2      2   Ram   Verma  ramgopal@gmail.com

# %%
df1.drop(columns='index', inplace=True)

# %%
df1
# Out:
#   first    last               email
# 0   Jai  Sharma  sharmaji@gmail.com
# 1   Tom  Thomas      tony@gmail.com
# 2   Ram   Verma  ramgopal@gmail.com

# %%
schema_df1 = df1.columns

# %%
schema_df1
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
schema_df1.tolist()
# Out:
# ['first', 'last', 'email']

# %%
df1.sort_index(ascending=False)
# Out:
#   first    last               email
# 2   Ram   Verma  ramgopal@gmail.com
# 1   Tom  Thomas      tony@gmail.com
# 0   Jai  Sharma  sharmaji@gmail.com

# %%
df1
# Out:
#   first    last               email
# 0   Jai  Sharma  sharmaji@gmail.com
# 1   Tom  Thomas      tony@gmail.com
# 2   Ram   Verma  ramgopal@gmail.com

# %%
filt = df1['last'] != 'Sharma'

# %%
filt
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
df1[filt]
# Out:
#   first    last               email
# 1   Tom  Thomas      tony@gmail.com
# 2   Ram   Verma  ramgopal@gmail.com
